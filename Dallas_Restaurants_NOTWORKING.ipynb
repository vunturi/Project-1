# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google developer API key
from gconfig import gkey

# %%
# geocoordinates and pullling restaurants within a radius of 
target_coordinates = "32.7766642,-96.79698789999999" # Coordinates for Dallas, TX 
target_radius = 50
target_type = "restaurant"
target_rated = "rating"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places = response.json()

# Print the json (pretty printed)
len(json.dumps(places, sort_keys=True))
# Out:
# 3172

# %%
print(json.dumps(places, indent=10, sort_keys=True))
# Out:
# {
#           "html_attributions": [],
#           "results": [
#                     {
#                               "geometry": {
#                                         "location": {
#                                                   "lat": 32.7766642,
#                                                   "lng": -96.79698789999999
#                                         },
#                                         "viewport": {
#                                                   "northeast": {
#                                                             "lat": 32.7780131802915,
#                                                             "lng": -96.7956389197085
#                                                   },
#                                                   "southwest": {
#                                                             "lat": 32.7753152197085,
#                                                             "lng": -96.7983368802915
# ...

# %%
results = places["results"]
# lets look at a single element 
results
# Out:
# [{'geometry': {'location': {'lat': 32.7766642, 'lng': -96.79698789999999},
#    'viewport': {'northeast': {'lat': 32.7780131802915,
#      'lng': -96.7956389197085},
#     'southwest': {'lat': 32.7753152197085, 'lng': -96.7983368802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'f0d7b066e913f19d0481d69adba1ba046ce8caa5',
#   'name': "Rubin's restaurant",
#   'photos': [{'height': 359,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110711611533329548761/photos">eliolyn garcetos</a>'],
#     'photo_reference': 'CmRaAAAAz5OolxqxLj3URWntnOppbb_dQoj_VLGuZGnWBxAbvDxcUCIje8wLC9wy0fOTVg_Mr_FDhrGsgyY2Jzteh06zIW32J7YiQMqHcBOP6ZVLiUwJ1LXx7WYLfMwvrT3VdvtiEhDW_vIHrLg6qDyH9EoA2WcVGhROy7zLJJl14096gU1vsP1sIQW6VQ',
#     'width': 480}],
#   'place_id': 'ChIJvz3I26eZToYRNwDl_GbjJdw',
#   'plus_code': {'compound_code': 'Q6G3+M6 Dallas, Texas, United States',
#    'global_code': '8645Q6G3+M6'},
# ...

# %%
rest_pd = pd.DataFrame(results)
rest_pd
# Out:
#                                             geometry  \
# 0  {'location': {'lat': 32.7766642, 'lng': -96.79...
# 1  {'location': {'lat': 32.7766642, 'lng': -96.79...
# 2  {'location': {'lat': 32.7766642, 'lng': -96.79...
# 3  {'location': {'lat': 32.7765299, 'lng': -96.79...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id                name  \
# 0  f0d7b066e913f19d0481d69adba1ba046ce8caa5  Rubin's restaurant
# 1  efc3a6e9fe3216bc7998c212e208d27600c5a5b7  Marcos Bond Molina
# 2  0a0264f78eaf052f774463f6c860831616b2a07b  Cheesecake Factory
# 3  ddcf84a959dec236f30d09725da07860580c9692            Harrison
#
#                                               photos  \
# ...

# %%
latitude = []
longitude = []

# %%
lat_rest = results["results"][0]["geometry"]["location"]["lat"]
lon_rest = results["results"][0]["geometry"]["location"]["lng"]


rest_pd["Lat"] = ""
rest_pd["Lng"] = ""
rest_pd.head()

for restaurant in places:
    lat_rest.append
    lon_rest.append
