# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
api_key='zb0GcvgfwyjRcY9Rw-V7CCINzDGu8fCRO0_5z6EAN0T77jh1n7Q8Xk87pi33DOK2a0pS19XzrsODFhojo1xyWWkz1D0UTOtW6IeFv5jdoml6ROzSYLBYFddnLtMmXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# URL for GET requests to retrieve restaurant data
url = 'https://api.yelp.com/v3/businesses/search'
params = {'catergories':"restaurants, All", 'location':'Dallas', "limit": 50, 'delivery': 'food delivery'}

# %%
# Making a get request to the API
req = requests.get(url, params=params, headers=headers)

# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [400]>

# %%
# Retrieving data and converting it into JSON
req_json = json.loads(req.text)

# %%
pd_df = req_json['businesses']
len(pd_df)
# Out:
# 50

# %%
pprint(pd_df)
# Out:
# [{'alias': 'pecan-lodge-dallas-3',
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                  {'alias': 'bbq', 'title': 'Barbeque'}],
#   'coordinates': {'latitude': 32.7835884, 'longitude': -96.7838669},
#   'display_phone': '(214) 748-8900',
#   'distance': 6357.232139011169,
#   'id': 'ycL1qii6EpKXoLgMMboBIQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aPP6Dp7IDXh6cjLlp33cg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2702 Main St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2702 Main St', 'Dallas, TX 75226'],
#                'state': 'TX',
#                'zip_code': '75226'},
#   'name': 'Pecan Lodge',
#   'phone': '+12147488900',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 4361,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/pecan-lodge-dallas-3?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'velvet-taco-dallas',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#                  {'alias': 'tacos', 'title': 'Tacos'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.8216823671486, 'longitude': -96.7853808991681},
#   'display_phone': '(214) 823-8358',
#   'distance': 2394.17683873596,
#   'id': 'GbKN-edIpqhNXH_iItk04w',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zvupNzPGNd2dOdJM59S2vw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3012 N Henderson Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['3012 N Henderson Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Velvet Taco',
#   'phone': '+12148238358',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 2566,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/velvet-taco-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'meso-maya-comida-y-copas-dallas-4',
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                  {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#   'coordinates': {'latitude': 32.7876872301983, 'longitude': -96.8049378803092},
#   'display_phone': '(214) 484-6555',
#   'distance': 5725.338433149188,
#   'id': 'vwQnJlj90NgYbbbVLQSpFg',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CvCM2sZuQU2q0kQatErZ_g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1611 Mckinney Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1611 Mckinney Ave', 'Dallas, TX 75202'],
#                'state': 'TX',
#                'zip_code': '75202'},
#   'name': 'Meso Maya Comida Y Copas',
#   'phone': '+12144846555',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1989,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/meso-maya-comida-y-copas-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'uchi-dallas',
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                  {'alias': 'sushi', 'title': 'Sushi Bars'},
#                  {'alias': 'seafood', 'title': 'Seafood'}],
#   'coordinates': {'latitude': 32.7968594931252, 'longitude': -96.8064853736551},
#   'display_phone': '(214) 855-5454',
#   'distance': 4723.460454329221,
#   'id': 'CPQEBDq7cspBB_AFYHvTDw',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/poj8fLu3CA7vRzMi2FxUNg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2817 Maple Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2817 Maple Ave', 'Dallas, TX 75201'],
#                'state': 'TX',
#                'zip_code': '75201'},
#   'name': 'Uchi',
#   'phone': '+12148555454',
#   'price': '$$$',
#   'rating': 4.5,
#   'review_count': 1140,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/uchi-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'maple-leaf-diner-dallas',
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#                  {'alias': 'diners', 'title': 'Diners'}],
#   'coordinates': {'latitude': 32.92347, 'longitude': -96.80524},
#   'display_phone': '(214) 434-1626',
#   'distance': 9375.606691264125,
#   'id': 'aH3iLs5URV5sY-kNKVFyLA',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZG7N9KRgoEBBq6XemryinA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '12817 Preston Rd',
#                'address2': 'Ste 129',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['12817 Preston Rd',
#                                    'Ste 129',
#                                    'Dallas, TX 75230'],
#                'state': 'TX',
#                'zip_code': '75230'},
#   'name': 'Maple Leaf Diner',
#   'phone': '+12144341626',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1894,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/maple-leaf-diner-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'rodeo-goat-dallas',
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                  {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'coordinates': {'latitude': 32.7971504231268, 'longitude': -96.8239863214264},
#   'display_phone': '(214) 741-4628',
#   'distance': 5147.945817852955,
#   'id': 'bULVB0Q87mn4u2sNPjXTTQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qpdC5Q9ImVZj_e6EL_lMRA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1926 Market Center Blvd',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1926 Market Center Blvd',
#                                    'Dallas, TX 75207'],
#                'state': 'TX',
#                'zip_code': '75207'},
#   'name': 'Rodeo Goat',
#   'phone': '+12147414628',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1767,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/rodeo-goat-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'rise-n-1-dallas',
#   'categories': [{'alias': 'french', 'title': 'French'},
#                  {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                  {'alias': 'desserts', 'title': 'Desserts'}],
#   'coordinates': {'latitude': 32.8501283339466, 'longitude': -96.8201696447052},
#   'display_phone': '(214) 366-9900',
#   'distance': 2209.761827649162,
#   'id': 'j6j8IFLUUQA1WgwGqawtkw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uov8jRtxNbBjoU-wj0zZvw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '5360 W Lovers Ln',
#                'address2': 'Ste 220',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['5360 W Lovers Ln',
#                                    'Ste 220',
#                                    'Dallas, TX 75209'],
#                'state': 'TX',
#                'zip_code': '75209'},
#   'name': 'rise n°1',
#   'phone': '+12143669900',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1233,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/rise-n-1-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'jimmys-food-store-dallas',
#   'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#                  {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                  {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#   'coordinates': {'latitude': 32.80413, 'longitude': -96.773666},
#   'display_phone': '(214) 823-6180',
#   'distance': 4628.964105338854,
#   'id': 'mXd9_jTBmaNn9lFVGo0XoA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9RX4HhssQYOaPMSzNAcTcw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4901 Bryan St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4901 Bryan St', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': "Jimmy's Food Store",
#   'phone': '+12148236180',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 842,
#   'transactions': ['pickup'],
#   'url': 'https://www.yelp.com/biz/jimmys-food-store-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'uncle-ubers-dallas-2',
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                  {'alias': 'burgers', 'title': 'Burgers'},
#                  {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'coordinates': {'latitude': 32.7834, 'longitude': -96.78341},
#   'display_phone': '(214) 653-8237',
#   'distance': 6392.720165393783,
#   'id': 'kvcQrj5CutHBfSgcg236EA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BeKenMWSMqUmraDfTtcTVA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2713 Commerce St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2713 Commerce St', 'Dallas, TX 75226'],
#                'state': 'TX',
#                'zip_code': '75226'},
#   'name': "Uncle Uber's",
#   'phone': '+12146538237',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 1157,
#   'transactions': ['delivery'],
#   'url': 'https://www.yelp.com/biz/uncle-ubers-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'hg-sply-co-dallas-dallas',
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#                  {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'coordinates': {'latitude': 32.8143559, 'longitude': -96.769792},
#   'display_phone': '(469) 334-0895',
#   'distance': 3973.4872117560194,
#   'id': '3Y4GDcv5MTepbFYMbAo4MQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JseGDjum0lp6pPx5mgg1bg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2008 Greenville Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2008 Greenville Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'HG SPLY CO - Dallas',
#   'phone': '+14693340895',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1470,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/hg-sply-co-dallas-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'mikes-chicken-dallas',
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'coordinates': {'latitude': 32.808448, 'longitude': -96.818527},
#   'display_phone': '(214) 443-7822',
#   'distance': 3791.4793164707935,
#   'id': '_m82_xIX_7WL4MQfw7CA5Q',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GuO4yebC6DlK_T6aPNY2pg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4234 Maple Ave',
#                'address2': None,
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4234 Maple Ave', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': "Mike's Chicken",
#   'phone': '+12144437822',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 765,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/mikes-chicken-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'hopdoddy-burger-bar-dallas-5',
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                  {'alias': 'beerbar', 'title': 'Beer Bar'},
#                  {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'coordinates': {'latitude': 32.8634651, 'longitude': -96.8072497},
#   'display_phone': '(214) 363-2337',
#   'distance': 2753.595910175625,
#   'id': 'RI0wzbqfyAgBL3xgFTzQ2Q',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hslxGwdOv9q1ntgIhw76YA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '6030 Luther Ln',
#                'address2': 'Ste 100',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['6030 Luther Ln',
#                                    'Ste 100',
#                                    'Dallas, TX 75225'],
#                'state': 'TX',
#                'zip_code': '75225'},
#   'name': 'Hopdoddy Burger Bar',
#   'phone': '+12143632337',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1184,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/hopdoddy-burger-bar-dallas-5?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'meddlesome-moth-dallas',
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#                  {'alias': 'gastropubs', 'title': 'Gastropubs'},
#                  {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'coordinates': {'latitude': 32.7968167432672, 'longitude': -96.8202942609787},
#   'display_phone': '(214) 628-7900',
#   'distance': 5045.335220567964,
#   'id': 'vOsy9SLr3bjIkHPWFYxVWQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYAng2ZqsCMsJMfblMW02g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1621 Oak Lawn Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1621 Oak Lawn Ave', 'Dallas, TX 75207'],
#                'state': 'TX',
#                'zip_code': '75207'},
#   'name': 'Meddlesome Moth',
#   'phone': '+12146287900',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1827,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/meddlesome-moth-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'ellens-dallas-4',
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#                  {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.7818955295251, 'longitude': -96.8076125410698},
#   'display_phone': '(469) 206-3339',
#   'distance': 6388.8661678353365,
#   'id': 'CREIs-59rrp8OhG9VppCqA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LFFqdsCc-onxBeh3j4Yptg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1790 N Record St',
#                'address2': None,
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1790 N Record St', 'Dallas, TX 75202'],
#                'state': 'TX',
#                'zip_code': '75202'},
#   'name': "Ellen's",
#   'phone': '+14692063339',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 2348,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/ellens-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'wabi-house-dallas',
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#                  {'alias': 'desserts', 'title': 'Desserts'},
#                  {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 32.8123013, 'longitude': -96.769967},
#   'display_phone': '(469) 779-6474',
#   'distance': 4123.300981249043,
#   'id': 'ZUBmtNBU0L45jIrMAgGeiQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfXyocokKD1hHaAGYLpRSw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1802 Greenville Ave',
#                'address2': 'Ste 100',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1802 Greenville Ave',
#                                    'Ste 100',
#                                    'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Wabi House',
#   'phone': '+14697796474',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1128,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/wabi-house-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'the-porch-dallas',
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#                  {'alias': 'newamerican', 'title': 'American (New)'},
#                  {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'coordinates': {'latitude': 32.82064248039, 'longitude': -96.784746955887},
#   'display_phone': '(214) 828-2916',
#   'distance': 2522.53565678719,
#   'id': '9uaSZzLB7CEHGc4mokQxig',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZwkvZQNkJjUHSPdkPjvCbQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2912 N Henderson Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2912 N Henderson Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'The Porch',
#   'phone': '+12148282916',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1299,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/the-porch-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'emporium-pies-dallas',
#   'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#                  {'alias': 'bakeries', 'title': 'Bakeries'}],
#   'coordinates': {'latitude': 32.7477188110352, 'longitude': -96.828125},
#   'display_phone': '(469) 206-6126',
#   'distance': 10477.333642792233,
#   'id': 'gMICrvlFC4zKGKcGDtpxUQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1HxU-L6tPXdYOvW0qIzAPA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '314 N Bishop Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['314 N Bishop Ave', 'Dallas, TX 75208'],
#                'state': 'TX',
#                'zip_code': '75208'},
#   'name': 'Emporium Pies',
#   'phone': '+14692066126',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 1149,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/emporium-pies-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'cane-rosso-dallas',
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                  {'alias': 'italian', 'title': 'Italian'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.782503, 'longitude': -96.785507},
#   'display_phone': '(214) 741-1188',
#   'distance': 6442.009813414365,
#   'id': 'kgmPMAHlFjWAILBGLUSKuw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pyfi7Y0YtFQjPS8pOIxT_A/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2612 Commerce St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2612 Commerce St', 'Dallas, TX 75226'],
#                'state': 'TX',
#                'zip_code': '75226'},
#   'name': 'Cane Rosso',
#   'phone': '+12147411188',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1441,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/cane-rosso-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'pappas-bros-steakhouse-dallas',
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                  {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'coordinates': {'latitude': 32.8668273689937, 'longitude': -96.8977529669342},
#   'display_phone': '(214) 366-2000',
#   'distance': 9592.160920715294,
#   'id': 'vOUOAoPRW27oNJFJLhkNNQ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pJjvgTwcEvUcofvyA0r-zQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '10477 Lombardy Ln',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['10477 Lombardy Ln', 'Dallas, TX 75220'],
#                'state': 'TX',
#                'zip_code': '75220'},
#   'name': 'Pappas Bros Steakhouse',
#   'phone': '+12143662000',
#   'price': '$$$$',
#   'rating': 4.5,
#   'review_count': 906,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/pappas-bros-steakhouse-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'steel-city-pops-lower-greenville-dallas',
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#                  {'alias': 'gourmet', 'title': 'Specialty Food'}],
#   'coordinates': {'latitude': 32.8143812, 'longitude': -96.7700277},
#   'display_phone': '(972) 525-7359',
#   'distance': 3955.642653098476,
#   'id': 'tfvOL6Qm4HKZn4sU_XuYWw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8GJPsF8fXA2H8iE8w0CiTw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2012 Greenville Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2012 Greenville Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Steel City Pops - Lower Greenville',
#   'phone': '+19725257359',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 621,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/steel-city-pops-lower-greenville-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'spiral-diner-and-bakery-dallas',
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#                  {'alias': 'bakeries', 'title': 'Bakeries'},
#                  {'alias': 'diners', 'title': 'Diners'}],
#   'coordinates': {'latitude': 32.75674, 'longitude': -96.82319},
#   'display_phone': '(214) 948-4747',
#   'distance': 9398.799560097907,
#   'id': 'Ij9ivfqGXtbqdYKyBEIFJA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/36IgA9UlZOAipXBQRSH90g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1101 N Beckley Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1101 N Beckley Ave', 'Dallas, TX 75203'],
#                'state': 'TX',
#                'zip_code': '75203'},
#   'name': 'Spiral Diner & Bakery',
#   'phone': '+12149484747',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1059,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/spiral-diner-and-bakery-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'lockhart-smokehouse-dallas',
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                  {'alias': 'bars', 'title': 'Bars'},
#                  {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#   'coordinates': {'latitude': 32.7493251, 'longitude': -96.828514},
#   'display_phone': '(214) 944-5521',
#   'distance': 10316.56094941739,
#   'id': 'GC8QmhLYqm5bGNPuyrvFvg',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ME5nnwp7wVRfa3kAWXaNtA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '400 W Davis St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['400 W Davis St', 'Dallas, TX 75208'],
#                'state': 'TX',
#                'zip_code': '75208'},
#   'name': 'Lockhart Smokehouse',
#   'phone': '+12149445521',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1835,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/lockhart-smokehouse-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'nazca-kitchen-dallas',
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                  {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.8816055276557, 'longitude': -96.767607162046},
#   'display_phone': '(214) 696-2922',
#   'distance': 5644.337906294852,
#   'id': 'VpVmd_qXec76rDkPI_Yohg',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y5CgJBV7hXlqUb5W8mfCQA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '8041 Walnut Hill Ln',
#                'address2': 'Ste 854',
#                'address3': None,
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['8041 Walnut Hill Ln',
#                                    'Ste 854',
#                                    'Dallas, TX 75231'],
#                'state': 'TX',
#                'zip_code': '75231'},
#   'name': 'Nazca Kitchen',
#   'phone': '+12146962922',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 787,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/nazca-kitchen-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'truck-yard-dallas',
#   'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#                  {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'coordinates': {'latitude': 32.814262, 'longitude': -96.771146},
#   'display_phone': '(469) 500-0139',
#   'distance': 3890.391359994464,
#   'id': 'QgyUJBNXPrbfGHaUUS4G7A',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I6hxRSiVH2CbfIbOG9etZQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '5624 Sears St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['5624 Sears St', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Truck Yard',
#   'phone': '+14695000139',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 930,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/truck-yard-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'perrys-steakhouse-and-grille-uptown-dallas-dallas',
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                  {'alias': 'seafood', 'title': 'Seafood'},
#                  {'alias': 'newamerican', 'title': 'American (New)'}],
#   'coordinates': {'latitude': 32.7911390285093, 'longitude': -96.8032053055572},
#   'display_phone': '(214) 855-5151',
#   'distance': 5332.559075140499,
#   'id': 'TySGn5WfokBuvSRlACtD_w',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/chi8e3y4gmUCuc-j1hkEnQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2000 McKinney Ave',
#                'address2': 'Ste 100',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2000 McKinney Ave',
#                                    'Ste 100',
#                                    'Dallas, TX 75201'],
#                'state': 'TX',
#                'zip_code': '75201'},
#   'name': "Perry's Steakhouse & Grille - Uptown Dallas",
#   'phone': '+12148555151',
#   'price': '$$$',
#   'rating': 4.5,
#   'review_count': 840,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/perrys-steakhouse-and-grille-uptown-dallas-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'maple-and-motor-dallas',
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'coordinates': {'latitude': 32.81524, 'longitude': -96.82703},
#   'display_phone': '(214) 522-4400',
#   'distance': 3629.3109459693296,
#   'id': 'croqa_T9y5o1R4R8P4o9iw',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jjS_S5K8ob2m9NZeF1MVCA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4810 Maple Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4810 Maple Ave', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': 'Maple and Motor',
#   'phone': '+12145224400',
#   'price': '$',
#   'rating': 4.0,
#   'review_count': 1348,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/maple-and-motor-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'crushcraft-thai-eats-dallas-7',
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#                  {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'coordinates': {'latitude': 32.79894, 'longitude': -96.8035},
#   'display_phone': '(972) 677-7038',
#   'distance': 4459.388889012281,
#   'id': 'AiGxPwiRcpd3fJumAA0ppw',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XIdKL2m4hB4_rDO7biHVmQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2800 Routh St',
#                'address2': 'Ste 150',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2800 Routh St',
#                                    'Ste 150',
#                                    'Dallas, TX 75201'],
#                'state': 'TX',
#                'zip_code': '75201'},
#   'name': 'Crushcraft Thai Eats',
#   'phone': '+19726777038',
#   'price': '$',
#   'rating': 4.0,
#   'review_count': 1087,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/crushcraft-thai-eats-dallas-7?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'bread-winners-cafe-and-bakery-dallas-9',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#                  {'alias': 'bakeries', 'title': 'Bakeries'}],
#   'coordinates': {'latitude': 32.80466, 'longitude': -96.79952},
#   'display_phone': '(214) 754-4940',
#   'distance': 3828.2313432124643,
#   'id': 'c52DnkG960PJO5vDHlV9VA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Un5YdavnwoxT5wkfos7QDQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3301 McKinney Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['3301 McKinney Ave', 'Dallas, TX 75204'],
#                'state': 'TX',
#                'zip_code': '75204'},
#   'name': 'Bread Winners Cafe & Bakery',
#   'phone': '+12147544940',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1657,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/bread-winners-cafe-and-bakery-dallas-9?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'botolino-gelato-artigianale-dallas',
#   'categories': [{'alias': 'gelato', 'title': 'Gelato'},
#                  {'alias': 'desserts', 'title': 'Desserts'},
#                  {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'coordinates': {'latitude': 32.815391160845, 'longitude': -96.7699820951065},
#   'display_phone': '(469) 776-9077',
#   'distance': 3881.7526982644167,
#   'id': 'yN86NZ8em4NMgb6Ub0fsBA',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4eKKsUh_iyvgVkmP12bwpQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2116 Greenville Ave',
#                'address2': None,
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2116 Greenville Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Botolino Gelato Artigianale',
#   'phone': '+14697769077',
#   'price': '$$',
#   'rating': 5.0,
#   'review_count': 287,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/botolino-gelato-artigianale-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'parliament-dallas-2',
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'coordinates': {'latitude': 32.797867, 'longitude': -96.798463},
#   'display_phone': '(469) 804-4321',
#   'distance': 4582.711372620416,
#   'id': 'VJyE0wCtZtoLev9YgXYpIQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AyqDwBIEytjACeyO-Lv--A/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2418 Allen St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2418 Allen St', 'Dallas, TX 75204'],
#                'state': 'TX',
#                'zip_code': '75204'},
#   'name': 'Parliament',
#   'phone': '+14698044321',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 470,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/parliament-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'eatzis-market-and-bakery-dallas-2',
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#                  {'alias': 'cafes', 'title': 'Cafes'}],
#   'coordinates': {'latitude': 32.8114855745709, 'longitude': -96.8063945232788},
#   'display_phone': '(214) 526-1515',
#   'distance': 3112.7908529330925,
#   'id': 'VfqvmTz67HmvokArp2Iikg',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C1isWmkuAKv0QUuf8jradw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3403 Oak Lawn Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['3403 Oak Lawn Ave', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': "Eatzi's Market & Bakery",
#   'phone': '+12145261515',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 822,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/eatzis-market-and-bakery-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'latin-deli-dallas',
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                  {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.855952, 'longitude': -96.749189},
#   'display_phone': '(214) 363-5551',
#   'distance': 5152.079218238896,
#   'id': 'Ngu58aTbW-BDffV7gJLc5w',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/emNziR89Hwv7QFf8IE5SLQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '5844 Abrams Rd',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['5844 Abrams Rd', 'Dallas, TX 75214'],
#                'state': 'TX',
#                'zip_code': '75214'},
#   'name': 'Latin Deli',
#   'phone': '+12143635551',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 532,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/latin-deli-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'klyde-warren-park-dallas',
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'coordinates': {'latitude': 32.7894745738813, 'longitude': -96.8015492750959},
#   'display_phone': '(214) 716-4500',
#   'distance': 5512.616594414618,
#   'id': 'ktb-qYO6-Dd13aHSANazUg',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TDnKjgPY8U1pL7NbIpOyEA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2012 Woodall Rodgers Fwy',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2012 Woodall Rodgers Fwy',
#                                    'Dallas, TX 75201'],
#                'state': 'TX',
#                'zip_code': '75201'},
#   'name': 'Klyde Warren Park',
#   'phone': '+12147164500',
#   'rating': 4.5,
#   'review_count': 466,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/klyde-warren-park-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'malai-kitchen-dallas',
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#                  {'alias': 'vietnamese', 'title': 'Vietnamese'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.808675, 'longitude': -96.79681},
#   'display_phone': '(214) 599-7857',
#   'distance': 3394.729111488454,
#   'id': 'jc2cJk3gWReiI4VRKGGtPg',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zqyk6FKTwIA7CCzzvAZw6w/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3699 McKinney Ave',
#                'address2': 'Ste 319',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['3699 McKinney Ave',
#                                    'Ste 319',
#                                    'Dallas, TX 75204'],
#                'state': 'TX',
#                'zip_code': '75204'},
#   'name': 'Malai Kitchen',
#   'phone': '+12145997857',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 989,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/malai-kitchen-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'twisted-root-burger-co-deep-ellum-dallas',
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                  {'alias': 'divebars', 'title': 'Dive Bars'},
#                  {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'coordinates': {'latitude': 32.78298, 'longitude': -96.78553},
#   'display_phone': '(214) 741-7668',
#   'distance': 6387.890062489715,
#   'id': 'm65eNPCMSlmUkN5PyUFE5g',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uXOmrkAxjO9hfyPpSuBPsg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2615 Commerce St',
#                'address2': None,
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2615 Commerce St', 'Dallas, TX 75226'],
#                'state': 'TX',
#                'zip_code': '75226'},
#   'name': 'Twisted Root Burger Co - Deep Ellum',
#   'phone': '+12147417668',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1224,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/twisted-root-burger-co-deep-ellum-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'dallas-arboretum-dallas',
#   'categories': [{'alias': 'gardens', 'title': 'Botanical Gardens'}],
#   'coordinates': {'latitude': 32.8215158309519, 'longitude': -96.7184063550695},
#   'display_phone': '(214) 515-6615',
#   'distance': 7917.500469592791,
#   'id': 'tHhaHPD2iMPueLBMxuW7BQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7LzUGEW37ZdT_7CUG15feQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '8525 Garland Rd',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['8525 Garland Rd', 'Dallas, TX 75218'],
#                'state': 'TX',
#                'zip_code': '75218'},
#   'name': 'Dallas Arboretum',
#   'phone': '+12145156615',
#   'rating': 4.5,
#   'review_count': 710,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/dallas-arboretum-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'cafe-izmir-dallas',
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#                  {'alias': 'tapas', 'title': 'Tapas Bars'},
#                  {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'coordinates': {'latitude': 32.832055, 'longitude': -96.7702649},
#   'display_phone': '(214) 826-7788',
#   'distance': 2915.619931370562,
#   'id': 'KzUVO55qzqrG-TNf2UFGKQ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xovXsZO-619h2l-Zf4IzoQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3711 Greenville Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['3711 Greenville Ave', 'Dallas, TX 75206'],
#                'state': 'TX',
#                'zip_code': '75206'},
#   'name': 'Cafe Izmir',
#   'phone': '+12148267788',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 656,
#   'transactions': ['delivery'],
#   'url': 'https://www.yelp.com/biz/cafe-izmir-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'pie-tap-pizza-workshop-bar-dallas-2',
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                  {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'coordinates': {'latitude': 32.79266, 'longitude': -96.82254},
#   'display_phone': '(469) 677-0997',
#   'distance': 5551.957471268643,
#   'id': 'QrkJf8yUDoOqQUVjljen8g',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KY_vmt1K0qCD-zb7MNwdJA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1212 Oak Lawn Ave',
#                'address2': 'Ste 131',
#                'address3': None,
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1212 Oak Lawn Ave',
#                                    'Ste 131',
#                                    'Dallas, TX 75207'],
#                'state': 'TX',
#                'zip_code': '75207'},
#   'name': 'Pie Tap Pizza Workshop + Bar',
#   'phone': '+14696770997',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 571,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/pie-tap-pizza-workshop-bar-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'italia-express-dallas-4',
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#                  {'alias': 'pizza', 'title': 'Pizza'}],
#   'coordinates': {'latitude': 32.8110667190261, 'longitude': -96.8111293398611},
#   'display_phone': '(214) 521-3300',
#   'distance': 3264.5219967478197,
#   'id': 'Hl0GqgW1I7yOhSyZyEmLAQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6tRyg9kvSuWJHCd5ZdbhEA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4000 Cedar Springs Rd',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4000 Cedar Springs Rd', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': 'Italia Express',
#   'phone': '+12145213300',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 467,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/italia-express-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'the-boiling-crab-dallas',
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#                  {'alias': 'seafood', 'title': 'Seafood'}],
#   'coordinates': {'latitude': 32.9159799858095, 'longitude': -96.7013626659912},
#   'display_phone': '(972) 272-7086',
#   'distance': 12607.961788782459,
#   'id': '4WYUJluX787H_FFihhCHjw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PXl57bVwVdch5Fe4-W3Q1w/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '10560 Walnut St',
#                'address2': 'Ste 100',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['10560 Walnut St',
#                                    'Ste 100',
#                                    'Dallas, TX 75243'],
#                'state': 'TX',
#                'zip_code': '75243'},
#   'name': 'The Boiling Crab',
#   'phone': '+19722727086',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1077,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/the-boiling-crab-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'eddie-vs-prime-seafood-dallas-2',
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                  {'alias': 'seafood', 'title': 'Seafood'},
#                  {'alias': 'lounges', 'title': 'Lounges'}],
#   'coordinates': {'latitude': 32.8180411940002, 'longitude': -96.8026394548507},
#   'display_phone': '(214) 890-1500',
#   'distance': 2343.5923114125676,
#   'id': 'uB2LOqdzP0SyltCjKILZ4Q',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SwfJReWEMDEEGMQrTNzLng/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4023 Oak Lawn Ave',
#                'address2': 'Ste 110',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4023 Oak Lawn Ave',
#                                    'Ste 110',
#                                    'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': "Eddie V's Prime Seafood",
#   'phone': '+12148901500',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 619,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/eddie-vs-prime-seafood-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'hatties-restaurant-dallas',
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#                  {'alias': 'newamerican', 'title': 'American (New)'}],
#   'coordinates': {'latitude': 32.7483102679253, 'longitude': -96.8282664567232},
#   'display_phone': '(214) 942-7400',
#   'distance': 10358.029810751535,
#   'id': 'x2z2ze7kB0rwI_9F9xCG5w',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S9VdskgfY_oin4jzoOzB-A/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '418 N Bishop Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['418 N Bishop Ave', 'Dallas, TX 75208'],
#                'state': 'TX',
#                'zip_code': '75208'},
#   'name': "Hattie's Restaurant",
#   'phone': '+12149427400',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 902,
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'url': 'https://www.yelp.com/biz/hatties-restaurant-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'frank-dallas-2',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'coordinates': {'latitude': 32.784096, 'longitude': -96.782949},
#   'display_phone': '(214) 997-3306',
#   'distance': 6327.106327712217,
#   'id': 'rm5vk91gV42Zvqq5rN387A',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wisxT0cQ_Yw0aSuD7Ac85w/o.jpg',
#   'is_closed': False,
#   'location': {'address1': 'Deep Ellum',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['Deep Ellum', 'Dallas, TX 75226'],
#                'state': 'TX',
#                'zip_code': '75226'},
#   'name': 'Frank',
#   'phone': '+12149973306',
#   'price': '$$$$',
#   'rating': 5.0,
#   'review_count': 209,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/frank-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'medina-oven-and-bar-dallas',
#   'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#                  {'alias': 'bars', 'title': 'Bars'},
#                  {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'coordinates': {'latitude': 32.7854930609465, 'longitude': -96.8093816936016},
#   'display_phone': '(214) 979-0003',
#   'distance': 5998.87793694198,
#   'id': 'OlYrVb5u-0UbmCevvhyEkQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yef1MWPowh1DCk9GgxgBcQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2304 Victory Park Ln',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2304 Victory Park Ln', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': 'Medina Oven & Bar',
#   'phone': '+12149790003',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 532,
#   'transactions': ['delivery', 'pickup'],
#   'url': 'https://www.yelp.com/biz/medina-oven-and-bar-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'sixth-floor-museum-at-dealey-plaza-dallas',
#   'categories': [{'alias': 'museums', 'title': 'Museums'}],
#   'coordinates': {'latitude': 32.77987, 'longitude': -96.80868},
#   'display_phone': '(214) 747-6660',
#   'distance': 6624.578964001155,
#   'id': 'KsYtUse_5IYrVizs_FfMrA',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JVzcgGmu2NOlkxUZL3RD9g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '411 Elm St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['411 Elm St', 'Dallas, TX 75202'],
#                'state': 'TX',
#                'zip_code': '75202'},
#   'name': 'Sixth Floor Museum at Dealey Plaza',
#   'phone': '+12147476660',
#   'rating': 4.5,
#   'review_count': 672,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/sixth-floor-museum-at-dealey-plaza-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'al-biernats-dallas-2',
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                  {'alias': 'seafood', 'title': 'Seafood'},
#                  {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 32.8203, 'longitude': -96.80266},
#   'display_phone': '(214) 219-2201',
#   'distance': 2089.819288107809,
#   'id': 'IjgbbeE38D01TSZEYJn6wg',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MTrDbqvUcqJVQWnQQFItng/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '4217 Oak Lawn Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['4217 Oak Lawn Ave', 'Dallas, TX 75219'],
#                'state': 'TX',
#                'zip_code': '75219'},
#   'name': "Al Biernat's",
#   'phone': '+12142192201',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 695,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/al-biernats-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'blues-burgers-dallas',
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                  {'alias': 'desserts', 'title': 'Desserts'},
#                  {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'coordinates': {'latitude': 32.82173, 'longitude': -96.8546999},
#   'display_phone': '(214) 750-9100',
#   'distance': 5364.713216047339,
#   'id': 'cAOTYSSwwgFCkP94_ZFQ2g',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rL4pk7meN8FgceeXPJCyAQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1820 W Mockingbird Ln',
#                'address2': 'Ste 44',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1820 W Mockingbird Ln',
#                                    'Ste 44',
#                                    'Dallas, TX 75235'],
#                'state': 'TX',
#                'zip_code': '75235'},
#   'name': 'Blues Burgers',
#   'phone': '+12147509100',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 402,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/blues-burgers-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'bolsa-dallas',
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#                  {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#                  {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 32.749241, 'longitude': -96.831991},
#   'display_phone': '(214) 367-9367',
#   'distance': 10409.403450439579,
#   'id': '3oiVVSQ7uDYLdnZeiRaRoQ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RiKZlVvO5jLNoAlmFh2aqQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '614 W Davis St',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['614 W Davis St', 'Dallas, TX 75208'],
#                'state': 'TX',
#                'zip_code': '75208'},
#   'name': 'Bolsa',
#   'phone': '+12143679367',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1041,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/bolsa-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'the-woolworth-dallas',
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#                  {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#                  {'alias': 'newamerican', 'title': 'American (New)'}],
#   'coordinates': {'latitude': 32.781324, 'longitude': -96.798692},
#   'display_phone': '(214) 814-0588',
#   'distance': 6420.422514525038,
#   'id': 'DP1I3daE5-mKznnAeA-Q3w',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G2edTzjaqJY3UtcqAtb0Ww/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1520 Elm St',
#                'address2': 'Ste 201',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['1520 Elm St',
#                                    'Ste 201',
#                                    'Dallas, TX 75204'],
#                'state': 'TX',
#                'zip_code': '75204'},
#   'name': 'The Woolworth',
#   'phone': '+12148140588',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 758,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/the-woolworth-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'},
#  {'alias': 'trulucks-dallas-2',
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                  {'alias': 'seafood', 'title': 'Seafood'}],
#   'coordinates': {'latitude': 32.794429968597, 'longitude': -96.80262550422},
#   'display_phone': '(214) 220-2401',
#   'distance': 4964.628194618731,
#   'id': 'Q85_DUiQCmtxmRL0sS56aw',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K34iq6X8C-vQ5ZyH8WGddg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2401 McKinney Ave',
#                'address2': '',
#                'address3': '',
#                'city': 'Dallas',
#                'country': 'US',
#                'display_address': ['2401 McKinney Ave', 'Dallas, TX 75201'],
#                'state': 'TX',
#                'zip_code': '75201'},
#   'name': "Truluck's",
#   'phone': '+12142202401',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 677,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/trulucks-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ'}]
