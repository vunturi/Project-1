# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
api_key='zb0GcvgfwyjRcY9Rw-V7CCINzDGu8fCRO0_5z6EAN0T77jh1n7Q8Xk87pi33DOK2a0pS19XzrsODFhojo1xyWWkz1D0UTOtW6IeFv5jdoml6ROzSYLBYFddnLtMmXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# URL for GET requests to retrieve restaurant data
url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'food', 'location':'Dallas', 'delivery': 'food delivery'}

# %%
# Making a get request to the API
req = requests.get(url, params=params, headers=headers)

# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [400]>

# %%
# Retrieving data and converting it into JSON
json.loads(req.text)
# Out:
# {'businesses': [{'id': '_m82_xIX_7WL4MQfw7CA5Q',
#    'alias': 'mikes-chicken-dallas',
#    'name': "Mike's Chicken",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GuO4yebC6DlK_T6aPNY2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikes-chicken-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 761,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.808448, 'longitude': -96.818527},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4234 Maple Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75219',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4234 Maple Ave', 'Dallas, TX 75219']},
#    'phone': '+12144437822',
#    'display_phone': '(214) 443-7822',
#    'distance': 3791.4793164707935},
#   {'id': 'ycL1qii6EpKXoLgMMboBIQ',
#    'alias': 'pecan-lodge-dallas-3',
#    'name': 'Pecan Lodge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aPP6Dp7IDXh6cjLlp33cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecan-lodge-dallas-3?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 4359,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7835884, 'longitude': -96.7838669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2702 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75226',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2702 Main St', 'Dallas, TX 75226']},
#    'phone': '+12147488900',
#    'display_phone': '(214) 748-8900',
#    'distance': 6357.232139011169},
#   {'id': 'u3CyA37M7V7a01rB9WuAng',
#    'alias': 'the-biscuit-bar-dallas-2',
#    'name': 'The Biscuit Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4nIaL-hGImUOSVl97tJ4vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-biscuit-bar-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 30,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.84572, 'longitude': -96.78746},
#    'transactions': [],
#    'location': {'address1': '6501 Hillcrest Ave',
#     'address2': 'Ste 150',
#     'address3': None,
#     'city': 'University Park',
#     'zip_code': '75205',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['6501 Hillcrest Ave',
#      'Ste 150',
#      'University Park, TX 75205']},
#    'phone': '+14694985974',
#    'display_phone': '(469) 498-5974',
#    'distance': 1429.753037525837},
#   {'id': 'kvcQrj5CutHBfSgcg236EA',
#    'alias': 'uncle-ubers-dallas-2',
#    'name': "Uncle Uber's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BeKenMWSMqUmraDfTtcTVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-ubers-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1157,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7834, 'longitude': -96.78341},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2713 Commerce St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75226',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2713 Commerce St', 'Dallas, TX 75226']},
#    'phone': '+12146538237',
#    'display_phone': '(214) 653-8237',
#    'distance': 6392.720165393783},
#   {'id': 'CREIs-59rrp8OhG9VppCqA',
#    'alias': 'ellens-dallas-4',
#    'name': "Ellen's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LFFqdsCc-onxBeh3j4Yptg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ellens-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2346,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7818955295251,
#     'longitude': -96.8076125410698},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1790 N Record St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1790 N Record St', 'Dallas, TX 75202']},
#    'phone': '+14692063339',
#    'display_phone': '(469) 206-3339',
#    'distance': 6388.8661678353365},
#   {'id': 'GbKN-edIpqhNXH_iItk04w',
#    'alias': 'velvet-taco-dallas',
#    'name': 'Velvet Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zvupNzPGNd2dOdJM59S2vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velvet-taco-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2567,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8216823671486,
#     'longitude': -96.7853808991681},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3012 N Henderson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3012 N Henderson Ave', 'Dallas, TX 75206']},
#    'phone': '+12148238358',
#    'display_phone': '(214) 823-8358',
#    'distance': 2394.17683873596},
#   {'id': 'bULVB0Q87mn4u2sNPjXTTQ',
#    'alias': 'rodeo-goat-dallas',
#    'name': 'Rodeo Goat',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qpdC5Q9ImVZj_e6EL_lMRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodeo-goat-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1766,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7971504231268,
#     'longitude': -96.8239863214264},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1926 Market Center Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75207',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1926 Market Center Blvd', 'Dallas, TX 75207']},
#    'phone': '+12147414628',
#    'display_phone': '(214) 741-4628',
#    'distance': 5147.945817852955},
#   {'id': 'AiGxPwiRcpd3fJumAA0ppw',
#    'alias': 'crushcraft-thai-eats-dallas-7',
#    'name': 'Crushcraft Thai Eats',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XIdKL2m4hB4_rDO7biHVmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crushcraft-thai-eats-dallas-7?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1085,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79894, 'longitude': -96.8035},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2800 Routh St',
#     'address2': 'Ste 150',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75201',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2800 Routh St', 'Ste 150', 'Dallas, TX 75201']},
#    'phone': '+19726777038',
#    'display_phone': '(972) 677-7038',
#    'distance': 4459.388889012281},
#   {'id': 'yh4x0P-4QZSLlB2wmRZ2Hg',
#    'alias': 'streets-fine-chicken-dallas-2',
#    'name': 'Streets Fine Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wfjh1oPTvJzTUWYoTKW7mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/streets-fine-chicken-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 524,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8100750190707,
#     'longitude': -96.8103479951717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3857 Cedar Springs Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75219',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3857 Cedar Springs Rd', 'Dallas, TX 75219']},
#    'phone': '+14699177140',
#    'display_phone': '(469) 917-7140',
#    'distance': 3349.0545590812435},
#   {'id': '9uaSZzLB7CEHGc4mokQxig',
#    'alias': 'the-porch-dallas',
#    'name': 'The Porch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZwkvZQNkJjUHSPdkPjvCbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-porch-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1298,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.82064248039, 'longitude': -96.784746955887},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2912 N Henderson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2912 N Henderson Ave', 'Dallas, TX 75206']},
#    'phone': '+12148282916',
#    'display_phone': '(214) 828-2916',
#    'distance': 2522.53565678719},
#   {'id': 'u5J69sPkUeKBKPGj-v9NnQ',
#    'alias': 'ten-ramen-dallas',
#    'name': 'Ten Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iaZEydnGcLmsxyGPvqhV_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ten-ramen-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 624,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7693609001565,
#     'longitude': -96.8353253702893},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1888 Sylvan Ave',
#     'address2': '',
#     'address3': 'Ste F 100',
#     'city': 'Dallas',
#     'zip_code': '75208',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1888 Sylvan Ave', 'Ste F 100', 'Dallas, TX 75208']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8402.875116459672},
#   {'id': 'QgyUJBNXPrbfGHaUUS4G7A',
#    'alias': 'truck-yard-dallas',
#    'name': 'Truck Yard',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I6hxRSiVH2CbfIbOG9etZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/truck-yard-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 930,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.814262, 'longitude': -96.771146},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5624 Sears St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5624 Sears St', 'Dallas, TX 75206']},
#    'phone': '+14695000139',
#    'display_phone': '(469) 500-0139',
#    'distance': 3890.391359994464},
#   {'id': 'vwQnJlj90NgYbbbVLQSpFg',
#    'alias': 'meso-maya-comida-y-copas-dallas-4',
#    'name': 'Meso Maya Comida Y Copas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CvCM2sZuQU2q0kQatErZ_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meso-maya-comida-y-copas-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1988,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7876872301983,
#     'longitude': -96.8049378803092},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1611 Mckinney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1611 Mckinney Ave', 'Dallas, TX 75202']},
#    'phone': '+12144846555',
#    'display_phone': '(214) 484-6555',
#    'distance': 5725.338433149188},
#   {'id': 'bB2ai7iXzB-CJFc1tcVXTw',
#    'alias': 'twisted-trompo-dallas',
#    'name': 'Twisted Trompo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PtWDdy9ZC12wIDrXZ09XBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twisted-trompo-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 180,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7795635919134,
#     'longitude': -96.8013510954492},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1211 Commerce St',
#     'address2': '',
#     'address3': None,
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1211 Commerce St', 'Dallas, TX 75202']},
#    'phone': '+12147609599',
#    'display_phone': '(214) 760-9599',
#    'distance': 6614.292202806332},
#   {'id': '4nA13xTTx1PWoI_uEuzXAQ',
#    'alias': 'el-tacaso-dallas',
#    'name': 'El Tacaso',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C0V1_ikXVWtBWfg7ww-mYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-tacaso-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 147,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.85917, 'longitude': -96.88143},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10025 Harry Hines Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75220',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['10025 Harry Hines Blvd', 'Dallas, TX 75220']},
#    'phone': '+14693359055',
#    'display_phone': '(469) 335-9055',
#    'distance': 7872.957359833989},
#   {'id': 'TxZWdv85JeNr7U8Q1mzsuw',
#    'alias': 'burning-rice-dallas',
#    'name': 'Burning Rice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UDyMv3YvHAs_pkETt1mhuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burning-rice-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 62,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8635550352729,
#     'longitude': -96.8062060340337},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6106 Luther Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Dallas',
#     'zip_code': '75225',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['6106 Luther Ln', 'Dallas, TX 75225']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2776.5239318316303},
#   {'id': 'aH3iLs5URV5sY-kNKVFyLA',
#    'alias': 'maple-leaf-diner-dallas',
#    'name': 'Maple Leaf Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZG7N9KRgoEBBq6XemryinA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maple-leaf-diner-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1890,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.92347, 'longitude': -96.80524},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '12817 Preston Rd',
#     'address2': 'Ste 129',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75230',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['12817 Preston Rd', 'Ste 129', 'Dallas, TX 75230']},
#    'phone': '+12144341626',
#    'display_phone': '(214) 434-1626',
#    'distance': 9375.606691264125},
#   {'id': 'xoLctIVzf81fx0fqHYwC5A',
#    'alias': 'smithy-dallas',
#    'name': 'Smithy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZT8iXbbcgd8GsIoCmTVDpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smithy-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 255,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.82095, 'longitude': -96.78556},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2927 N Henderson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2927 N Henderson Ave', 'Dallas, TX 75206']},
#    'phone': '+12143161984',
#    'display_phone': '(214) 316-1984',
#    'distance': 2454.178304288953},
#   {'id': 'DzbMhg4p-foF9NnAOod7aA',
#    'alias': 'bbbop-seoul-kitchen-dallas-2',
#    'name': 'bbbop Seoul Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NYFUzzRJcBeeWmHhTktdBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bbbop-seoul-kitchen-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 616,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.85215, 'longitude': -96.77006},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5323 Greenville Ave',
#     'address2': 'Ste 5',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5323 Greenville Ave', 'Ste 5', 'Dallas, TX 75206']},
#    'phone': '+12148129342',
#    'display_phone': '(214) 812-9342',
#    'distance': 3180.62585594601},
#   {'id': '8B2asBf5t77_9V2RH20YPg',
#    'alias': 'wingbucket-dallas',
#    'name': 'WingBucket',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kgzv2fiD0wuZIcJBJbs23A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wingbucket-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 466,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7800568007201,
#     'longitude': -96.8015836662705},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1200 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1200 Main St', 'Dallas, TX 75202']},
#    'phone': '+12147609491',
#    'display_phone': '(214) 760-9491',
#    'distance': 6559.741678105639}],
#  'total': 15200,
#  'region': {'center': {'longitude': -96.800537109375,
#    'latitude': 32.839043482398054}}}
