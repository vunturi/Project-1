# %%
import pandas as pd
import json
import requests

# %%
api_key='zb0GcvgfwyjRcY9Rw-V7CCINzDGu8fCRO0_5z6EAN0T77jh1n7Q8Xk87pi33DOK2a0pS19XzrsODFhojo1xyWWkz1D0UTOtW6IeFv5jdoml6ROzSYLBYFddnLtMmXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# URL for GET requests to retrieve restaurant data
url = 'https://api.yelp.com/v3/businesses/search'
params = {'categories':'restaurant', 'location':'Dallas', 'sort_by': 'rating',
          'sort_by': 'review_count'}

# %%
# Making a get request to the API
req = requests.get(url, params=params, headers=headers)

# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [400]>

# %%
# Retrieving data and converting it into JSON
json.loads(req.text)
# Out:
# {'businesses': [{'id': 'ycL1qii6EpKXoLgMMboBIQ',
#    'alias': 'pecan-lodge-dallas-3',
#    'name': 'Pecan Lodge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9aPP6Dp7IDXh6cjLlp33cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pecan-lodge-dallas-3?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 4361,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7835884, 'longitude': -96.7838669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2702 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75226',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2702 Main St', 'Dallas, TX 75226']},
#    'phone': '+12147488900',
#    'display_phone': '(214) 748-8900',
#    'distance': 6357.232139011169},
#   {'id': 'GbKN-edIpqhNXH_iItk04w',
#    'alias': 'velvet-taco-dallas',
#    'name': 'Velvet Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zvupNzPGNd2dOdJM59S2vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velvet-taco-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2566,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8216823671486,
#     'longitude': -96.7853808991681},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3012 N Henderson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3012 N Henderson Ave', 'Dallas, TX 75206']},
#    'phone': '+12148238358',
#    'display_phone': '(214) 823-8358',
#    'distance': 2394.17683873596},
#   {'id': 'QbuAgiAMWR7wrLKU7XSi-g',
#    'alias': 'kennys-wood-fired-grill-dallas-2',
#    'name': "Kenny's Wood Fired Grill",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xyRh1mjgBepfSNab-541SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kennys-wood-fired-grill-dallas-2?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2377,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.9534613031095,
#     'longitude': -96.8235682144482},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5000 Belt Line Rd',
#     'address2': 'Ste 775',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75254',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5000 Belt Line Rd', 'Ste 775', 'Dallas, TX 75254']},
#    'phone': '+19723929663',
#    'display_phone': '(972) 392-9663',
#    'distance': 12903.10317414666},
#   {'id': 'CREIs-59rrp8OhG9VppCqA',
#    'alias': 'ellens-dallas-4',
#    'name': "Ellen's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LFFqdsCc-onxBeh3j4Yptg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ellens-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2347,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7818955295251,
#     'longitude': -96.8076125410698},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1790 N Record St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1790 N Record St', 'Dallas, TX 75202']},
#    'phone': '+14692063339',
#    'display_phone': '(469) 206-3339',
#    'distance': 6388.8661678353365},
#   {'id': 'mzsZGshkc8_J5bo0MgrzBg',
#    'alias': 'ida-claire-addison',
#    'name': 'Ida Claire',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m88EWxrYj1prCiB-2ABkMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ida-claire-addison?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 2031,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9545, 'longitude': -96.82578},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5001 Belt Line Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Addison',
#     'zip_code': '75254',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5001 Belt Line Rd', 'Addison, TX 75254']},
#    'phone': '+12143778227',
#    'display_phone': '(214) 377-8227',
#    'distance': 13042.334753516088},
#   {'id': 'vwQnJlj90NgYbbbVLQSpFg',
#    'alias': 'meso-maya-comida-y-copas-dallas-4',
#    'name': 'Meso Maya Comida Y Copas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CvCM2sZuQU2q0kQatErZ_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meso-maya-comida-y-copas-dallas-4?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1989,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7876872301983,
#     'longitude': -96.8049378803092},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1611 Mckinney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75202',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1611 Mckinney Ave', 'Dallas, TX 75202']},
#    'phone': '+12144846555',
#    'display_phone': '(214) 484-6555',
#    'distance': 5725.338433149188},
#   {'id': '6EdQdLl419ehp4nE96n4Hg',
#    'alias': 'gen-korean-bbq-house-carrollton',
#    'name': 'Gen Korean BBQ House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5yyPjrvsJ07MIBcBnlpxHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gen-korean-bbq-house-carrollton?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1896,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9815389, 'longitude': -96.9086354},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2540 Old Denton Rd',
#     'address2': 'Ste 134',
#     'address3': None,
#     'city': 'Carrollton',
#     'zip_code': '75006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2540 Old Denton Rd',
#      'Ste 134',
#      'Carrollton, TX 75006']},
#    'phone': '+14698925669',
#    'display_phone': '(469) 892-5669',
#    'distance': 18785.230460513325},
#   {'id': 'aH3iLs5URV5sY-kNKVFyLA',
#    'alias': 'maple-leaf-diner-dallas',
#    'name': 'Maple Leaf Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZG7N9KRgoEBBq6XemryinA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maple-leaf-diner-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1893,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.92347, 'longitude': -96.80524},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '12817 Preston Rd',
#     'address2': 'Ste 129',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75230',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['12817 Preston Rd', 'Ste 129', 'Dallas, TX 75230']},
#    'phone': '+12144341626',
#    'display_phone': '(214) 434-1626',
#    'distance': 9375.606691264125},
#   {'id': 'GC8QmhLYqm5bGNPuyrvFvg',
#    'alias': 'lockhart-smokehouse-dallas',
#    'name': 'Lockhart Smokehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ME5nnwp7wVRfa3kAWXaNtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lockhart-smokehouse-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1835,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7493251, 'longitude': -96.828514},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '400 W Davis St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75208',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['400 W Davis St', 'Dallas, TX 75208']},
#    'phone': '+12149445521',
#    'display_phone': '(214) 944-5521',
#    'distance': 10316.56094941739},
#   {'id': 'vOsy9SLr3bjIkHPWFYxVWQ',
#    'alias': 'meddlesome-moth-dallas',
#    'name': 'Meddlesome Moth',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYAng2ZqsCMsJMfblMW02g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meddlesome-moth-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1827,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7968167432672,
#     'longitude': -96.8202942609787},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1621 Oak Lawn Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75207',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1621 Oak Lawn Ave', 'Dallas, TX 75207']},
#    'phone': '+12146287900',
#    'display_phone': '(214) 628-7900',
#    'distance': 5045.335220567964},
#   {'id': 'bULVB0Q87mn4u2sNPjXTTQ',
#    'alias': 'rodeo-goat-dallas',
#    'name': 'Rodeo Goat',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qpdC5Q9ImVZj_e6EL_lMRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodeo-goat-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1767,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7971504231268,
#     'longitude': -96.8239863214264},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1926 Market Center Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75207',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1926 Market Center Blvd', 'Dallas, TX 75207']},
#    'phone': '+12147414628',
#    'display_phone': '(214) 741-4628',
#    'distance': 5147.945817852955},
#   {'id': 'c52DnkG960PJO5vDHlV9VA',
#    'alias': 'bread-winners-cafe-and-bakery-dallas-9',
#    'name': 'Bread Winners Cafe & Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Un5YdavnwoxT5wkfos7QDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-winners-cafe-and-bakery-dallas-9?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1657,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.80466, 'longitude': -96.79952},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3301 McKinney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75204',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3301 McKinney Ave', 'Dallas, TX 75204']},
#    'phone': '+12147544940',
#    'display_phone': '(214) 754-4940',
#    'distance': 3828.2313432124643},
#   {'id': '3Y4GDcv5MTepbFYMbAo4MQ',
#    'alias': 'hg-sply-co-dallas-dallas',
#    'name': 'HG SPLY CO - Dallas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JseGDjum0lp6pPx5mgg1bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hg-sply-co-dallas-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1470,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8143559, 'longitude': -96.769792},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2008 Greenville Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2008 Greenville Ave', 'Dallas, TX 75206']},
#    'phone': '+14693340895',
#    'display_phone': '(469) 334-0895',
#    'distance': 3973.4872117560194},
#   {'id': 'kgmPMAHlFjWAILBGLUSKuw',
#    'alias': 'cane-rosso-dallas',
#    'name': 'Cane Rosso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pyfi7Y0YtFQjPS8pOIxT_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cane-rosso-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1441,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.782503, 'longitude': -96.785507},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2612 Commerce St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75226',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2612 Commerce St', 'Dallas, TX 75226']},
#    'phone': '+12147411188',
#    'display_phone': '(214) 741-1188',
#    'distance': 6442.009813414365},
#   {'id': 'croqa_T9y5o1R4R8P4o9iw',
#    'alias': 'maple-and-motor-dallas',
#    'name': 'Maple and Motor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jjS_S5K8ob2m9NZeF1MVCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maple-and-motor-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1348,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.81524, 'longitude': -96.82703},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4810 Maple Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75219',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4810 Maple Ave', 'Dallas, TX 75219']},
#    'phone': '+12145224400',
#    'display_phone': '(214) 522-4400',
#    'distance': 3629.3109459693296},
#   {'id': 'pJ-oCyduYMS1kuQqCqgJyg',
#    'alias': 'the-rustic-dallas',
#    'name': 'The Rustic',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pFIpf79IUvcoxW9iuNNR1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-rustic-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1312,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.8049063295879,
#     'longitude': -96.7942075248801},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3656 Howell St',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75204',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3656 Howell St', 'Dallas, TX 75204']},
#    'phone': '+12147300596',
#    'display_phone': '(214) 730-0596',
#    'distance': 3841.6770755301995},
#   {'id': '9uaSZzLB7CEHGc4mokQxig',
#    'alias': 'the-porch-dallas',
#    'name': 'The Porch',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZwkvZQNkJjUHSPdkPjvCbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-porch-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1299,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.82064248039, 'longitude': -96.784746955887},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2912 N Henderson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75206',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2912 N Henderson Ave', 'Dallas, TX 75206']},
#    'phone': '+12148282916',
#    'display_phone': '(214) 828-2916',
#    'distance': 2522.53565678719},
#   {'id': '2xUdy5NDvYDoF01vKGU2uQ',
#    'alias': 'the-ranch-irving',
#    'name': 'The Ranch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ajb0eqA8dKQZQyn9dtjEkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ranch-irving?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1299,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.889514, 'longitude': -96.95823217},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '857 W John Carpenter Fwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Irving',
#     'zip_code': '75039',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['857 W John Carpenter Fwy', 'Irving, TX 75039']},
#    'phone': '+19725067262',
#    'display_phone': '(972) 506-7262',
#    'distance': 15760.28498247926},
#   {'id': 'j6j8IFLUUQA1WgwGqawtkw',
#    'alias': 'rise-n-1-dallas',
#    'name': 'rise n°1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uov8jRtxNbBjoU-wj0zZvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rise-n-1-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1233,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8501283339466,
#     'longitude': -96.8201696447052},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5360 W Lovers Ln',
#     'address2': 'Ste 220',
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75209',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5360 W Lovers Ln', 'Ste 220', 'Dallas, TX 75209']},
#    'phone': '+12143669900',
#    'display_phone': '(214) 366-9900',
#    'distance': 2209.761827649162},
#   {'id': 'm65eNPCMSlmUkN5PyUFE5g',
#    'alias': 'twisted-root-burger-co-deep-ellum-dallas',
#    'name': 'Twisted Root Burger Co - Deep Ellum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uXOmrkAxjO9hfyPpSuBPsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/twisted-root-burger-co-deep-ellum-dallas?adjust_creative=QtSjttfQC4A-pcRDoc4zGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=QtSjttfQC4A-pcRDoc4zGQ',
#    'review_count': 1224,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.78298, 'longitude': -96.78553},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2615 Commerce St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dallas',
#     'zip_code': '75226',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2615 Commerce St', 'Dallas, TX 75226']},
#    'phone': '+12147417668',
#    'display_phone': '(214) 741-7668',
#    'distance': 6387.890062489715}],
#  'total': 7000,
#  'region': {'center': {'longitude': -96.800537109375,
#    'latitude': 32.839043482398054}}}
